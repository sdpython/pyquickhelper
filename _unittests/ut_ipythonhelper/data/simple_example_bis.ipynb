# %% [markdown]
# # Simple example

# %%
import pyquickhelper

# %%
from pyquickhelper.loghelper import str2datetime
str2datetime("2015-03-02")
# Out:
# datetime.datetime(2015, 3, 2, 0, 0)

# %% [markdown]
# Equation: $x^2$

# %%
pyquickhelper.ipythonhelper.store_notebook_path()

# %%
theNotebook = theNotebook.split("\\")[-1]

# %%
pyquickhelper.nb2slides(theNotebook, theNotebook + ".html")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-ba3a5a23a244> in <module>()
# ----> 1 pyquickhelper.nb2slides(theNotebook, theNotebook + ".html")
#
# C:\xadupre\__home_\_data\GitHub\pyquickhelper\src\pyquickhelper\helpgen\process_notebook_api.py in nb2slides(nb_file, outfile, add_tag)
#      87     if add_tag:
#      88         run = NotebookRunner(nb)
# ---> 89         run.add_tag_slide()
#      90         nb = run.nb
#      91
#
# C:\xadupre\__home_\_data\GitHub\pyquickhelper\src\pyquickhelper\ipythonhelper\notebook_runner.py in add_tag_slide(self, max_nb_cell, max_nb_line)
#     487         nbline = 0
#     488         nbcell = 0
# --> 489         for i, cell in enumerate(self.iter_cells()):
#     490             meta = cell.metadata
#     491             if "slideshow" in meta:
#
# C:\xadupre\__home_\_data\GitHub\pyquickhelper\src\pyquickhelper\ipythonhelper\notebook_runner.py in iter_cells(self)
#     377                     yield cell
#     378         else:
# --> 379             for cell in self.nb.cells:
#     380                 yield cell
#     381
#
# AttributeError: 'NotebookRunner' object has no attribute 'cells'

# %%
nb = pyquickhelper.ipythonhelper.NotebookRunner(theNotebook)

# %%
len(nb)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-d0a0afe567d8> in <module>()
# ----> 1 len(nb)
#
# C:\xadupre\__home_\_data\GitHub\pyquickhelper\src\pyquickhelper\ipythonhelper\notebook_runner.py in __len__(self)
#     405         .. versionadded:: 1.1
#     406         """
# --> 407         return sum(1 for _ in self.iter_cells())
#     408
#     409     def cell_type(self, cell):
#
# C:\xadupre\__home_\_data\GitHub\pyquickhelper\src\pyquickhelper\ipythonhelper\notebook_runner.py in <genexpr>(.0)
#     405         .. versionadded:: 1.1
#     406         """
# --> 407         return sum(1 for _ in self.iter_cells())
#     408
#     409     def cell_type(self, cell):
#
# C:\xadupre\__home_\_data\GitHub\pyquickhelper\src\pyquickhelper\ipythonhelper\notebook_runner.py in iter_cells(self)
#     377                     yield cell
#     378         else:
# --> 379             for cell in self.nb.cells:
#     380                 yield cell
#     381
#
# AttributeError: 'str' object has no attribute 'cells'
